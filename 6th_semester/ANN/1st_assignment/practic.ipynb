# %%
import numpy
import pandas
import matplotlib
import cv2

print(f"Numpy       :{numpy.__version__}")
print(f"pandas      :{pandas.__version__}")
print(f"matplotlib  :{matplotlib.__version__}")
print(f"Opencv     :{cv2.__version__}")
# Out:
# Numpy       :2.5.2
# pandas      :3.0.5
# matplotlib  :3.11.1
# Opencv     :5.0.0

# %%
# Loading 3000 images from dataset 
import cv2
import os 

ds_path = "/run/media/mozam/New Volume/University/6th_semester/ANN/Dataset/animals"

images = []
labels = []

for label in os.listdir(ds_path):
    folder_path = os.path.join(ds_path, label)

    for file in os.listdir(folder_path):
        image_path = os.path.join(folder_path, file)

        image =cv2.imread(image_path)

        if image is not None:
            image = cv2.resize(image,(32,32))

            images.append(image)
            labels.append(label)

print("Total images:", len(images))
print("Classes:",set(labels))
# Out:
# Total images: 3000
# Classes: {'dog', 'horse', 'elephant'}
